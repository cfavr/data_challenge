# %%
import pandas as pd

data = pd.read_csv('data/train.csv', index_col = 0, dtype={'multiple_full_time_jobs': 'boolean', 'combined_multiple_jobs': 'boolean'}).reset_index(drop=True)
strCols = data.select_dtypes(object).columns
for i in strCols:
    data[i] = data[i].str.strip()
#data = data.sample(frac=0.1)
data = data.fillna(True)
data.HIREDT = data.HIREDT.apply(pd.to_datetime, format = "%m/%d/%y")
data['daysexperience'] = (pd.to_datetime('10/7/23', format = "%m/%d/%y") - data.HIREDT ).dt.days
data_num = ['RATE', 'HRSWKD', 'daysexperience']
data_drop = ['AGY', 'HIREDT']#, 'multiple_full_time_jobs', 'combined_multiple_jobs']
data.drop(data_drop, axis=1, inplace=True)

important_features = ['daysexperience', 'RATE', 'RACE', 'SEX', 'MI', 'HRSWKD', 'JC.TITLE']

data_to_onehot = ['NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'RACE', 'SEX', 'EMPTYPE', 'STATENUM', 'multiple_full_time_jobs', 'combined_multiple_jobs']

from sklearn.model_selection import train_test_split
X = data.drop('ANNUAL', axis=1)
y = data.ANNUAL

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.compose import TransformedTargetRegressor
import numpy as np
import scipy as sp
regressor = LinearRegression(n_jobs=-1) #np.log10 sp.special.exp10
#regressor = TransformedTargetRegressor(
#        regressor=Ridge(alpha=5e-1), func=None, inverse_func=None
#    )
transformer = make_column_transformer(
    (OneHotEncoder(handle_unknown = 'infrequent_if_exist', drop='if_binary'), data_to_onehot),
    remainder = 'passthrough',
)
pipe = Pipeline([('transformer', transformer), ('regressor', regressor)])

pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 0.8823891243359261

# %%
import itertools
resDict = dict()
def findsubsets(s, n):
    return list(itertools.combinations(s, n))

for a in list(np.arange(5,len(X_train.columns))):
    resInnerDict = dict()
    for i in findsubsets(X_train.columns,a):
        cols = list(i)
        data_to_onehot = ['NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'RACE', 'SEX', 'EMPTYPE', 'STATENUM', 'multiple_full_time_jobs', 'combined_multiple_jobs']
        data_to_onehot = list(set(cols) & set(data_to_onehot))
        transformer = make_column_transformer(
        (OneHotEncoder(handle_unknown = 'infrequent_if_exist', drop='if_binary'), data_to_onehot),
        remainder = 'passthrough',
        )
        pipe = Pipeline([('transformer', transformer), ('regressor', regressor)])
        pipe.fit(X_train[cols], y_train)
        scoring = pipe.score(X_test[cols], y_test)
        resInnerDict[i] = scoring
    resDict[a] = resInnerDict
# Out:
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 7] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/clement/.virtualenvs/jupyter/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
list(np.arange(5,len(X_train.columns)))
# Out:
# [5, 6, 7, 8, 9, 10, 11, 12]

# %%
resDict
# Out:
# {}

# %%
sorted_list = sorted(resDict.items(), key = lambda x:x[1], reverse = True)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'EMPTYPE'), 0.9184249048620595)
for i in sorted_list:
    print(i)
# Out:
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'EMPTYPE'), 0.9184249048620595)
# (('NAME', 'MI', 'JC.TITLE', 'EMPTYPE', 'HRSWKD'), 0.9159587460808758)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'EMPTYPE'), 0.9151937737310629)
# (('NAME', 'MI', 'JC.TITLE', 'EMPTYPE', 'RATE'), 0.9151061423018075)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'EMPTYPE'), 0.9151048321226276)
# (('NAME', 'MI', 'JC.TITLE', 'EMPTYPE', 'combined_multiple_jobs'), 0.9150939853077908)
# (('NAME', 'MI', 'JC.TITLE', 'EMPTYPE', 'multiple_full_time_jobs'), 0.9150818474944056)
# (('NAME', 'MI', 'JOBCLASS', 'EMPTYPE', 'HRSWKD'), 0.9127820429824691)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'HRSWKD'), 0.9123827349588269)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'EMPTYPE'), 0.9119882560207548)
# (('NAME', 'MI', 'JOBCLASS', 'EMPTYPE', 'RATE'), 0.9119830782967567)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'EMPTYPE'), 0.9118911213360271)
# (('NAME', 'MI', 'JOBCLASS', 'EMPTYPE', 'multiple_full_time_jobs'), 0.9118621731325398)
# (('NAME', 'MI', 'JOBCLASS', 'EMPTYPE', 'combined_multiple_jobs'), 0.9118620875632399)
# (('NAME', 'MI', 'JC.TITLE', 'EMPTYPE', 'STATENUM'), 0.909546977951244)
# (('NAME', 'MI', 'JOBCLASS', 'EMPTYPE', 'STATENUM'), 0.9035065973972376)
# (('NAME', 'MI', 'JC.TITLE', 'HRSWKD', 'STATENUM'), 0.9033066422202439)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'RATE'), 0.9013321651071703)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'RACE'), 0.8999695720106992)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'SEX'), 0.8999614287025903)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'combined_multiple_jobs'), 0.8999000845624049)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'multiple_full_time_jobs'), 0.8999000425385864)
# (('NAME', 'MI', 'JOBCLASS', 'RATE', 'HRSWKD'), 0.8969582624819942)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'HRSWKD'), 0.8968904176051229)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'HRSWKD'), 0.8967592387165532)
# (('NAME', 'MI', 'JOBCLASS', 'HRSWKD', 'multiple_full_time_jobs'), 0.8966963424258578)
# (('NAME', 'MI', 'JOBCLASS', 'HRSWKD', 'combined_multiple_jobs'), 0.8966963424258578)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'STATENUM'), 0.8929716950438966)
# (('NAME', 'MI', 'JC.TITLE', 'STATENUM', 'daysexperience'), 0.8912813983186622)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'STATENUM'), 0.8899201356595119)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'STATENUM'), 0.8899147223085867)
# (('NAME', 'MI', 'JC.TITLE', 'RATE', 'STATENUM'), 0.8898770227284069)
# (('NAME', 'MI', 'JC.TITLE', 'STATENUM', 'combined_multiple_jobs'), 0.8898259110311266)
# (('NAME', 'MI', 'JC.TITLE', 'STATENUM', 'multiple_full_time_jobs'), 0.8898253935943046)
# (('NAME', 'MI', 'JOBCLASS', 'HRSWKD', 'STATENUM'), 0.8888375281834053)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'RATE'), 0.8856515657221207)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'RATE'), 0.8856424177916212)
# (('NAME', 'MI', 'JOBCLASS', 'RATE', 'multiple_full_time_jobs'), 0.8855294278388968)
# (('NAME', 'MI', 'JOBCLASS', 'RATE', 'combined_multiple_jobs'), 0.8855294278388968)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'SEX'), 0.8840387320550592)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'combined_multiple_jobs'), 0.8839668469792837)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'multiple_full_time_jobs'), 0.8839662617740095)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'combined_multiple_jobs'), 0.8839480736298965)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'multiple_full_time_jobs'), 0.8839480635463868)
# (('NAME', 'MI', 'JOBCLASS', 'multiple_full_time_jobs', 'combined_multiple_jobs'), 0.8838670629041674)
# (('NAME', 'MI', 'JOBCLASS', 'STATENUM', 'daysexperience'), 0.8767415419718713)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'STATENUM'), 0.8751772057460384)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'STATENUM'), 0.8751596710406964)
# (('NAME', 'MI', 'JOBCLASS', 'RATE', 'STATENUM'), 0.8751022503136227)
# (('NAME', 'MI', 'JOBCLASS', 'STATENUM', 'multiple_full_time_jobs'), 0.8750504424707718)
# (('NAME', 'MI', 'JOBCLASS', 'STATENUM', 'combined_multiple_jobs'), 0.8750499453195624)
# (('NAME', 'MI', 'JC.TITLE', 'RATE', 'HRSWKD'), 0.8340039957978964)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'HRSWKD'), 0.8327895406209472)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'HRSWKD'), 0.8325313902049172)
# (('NAME', 'MI', 'JC.TITLE', 'HRSWKD', 'multiple_full_time_jobs'), 0.8324446504926567)
# (('NAME', 'MI', 'JC.TITLE', 'HRSWKD', 'combined_multiple_jobs'), 0.8324446504926567)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'RATE'), 0.8227396447328911)
# (('NAME', 'MI', 'JC.TITLE', 'RATE', 'multiple_full_time_jobs'), 0.8227301367221065)
# (('NAME', 'MI', 'JC.TITLE', 'RATE', 'combined_multiple_jobs'), 0.8227301367221065)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'RATE'), 0.8222503299803217)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'SEX'), 0.819773614210513)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'combined_multiple_jobs'), 0.8197297840906074)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'multiple_full_time_jobs'), 0.8196718962264329)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'combined_multiple_jobs'), 0.8196716099267951)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'multiple_full_time_jobs'), 0.8196350758411441)
# (('NAME', 'MI', 'JC.TITLE', 'multiple_full_time_jobs', 'combined_multiple_jobs'), 0.8195132226119658)
# (('NAME', 'MI', 'JC.TITLE', 'EMPTYPE', 'daysexperience'), 0.4958075099536895)
# (('NAME', 'MI', 'JOBCLASS', 'EMPTYPE', 'daysexperience'), 0.4953249348630886)
# (('NAME', 'MI', 'JC.TITLE', 'RATE', 'daysexperience'), 0.47112397345349044)
# (('NAME', 'MI', 'JOBCLASS', 'JC.TITLE', 'daysexperience'), 0.4423921894618408)
# (('NAME', 'MI', 'JC.TITLE', 'SEX', 'daysexperience'), 0.41437128246020427)
# (('NAME', 'MI', 'JOBCLASS', 'SEX', 'daysexperience'), 0.41330628725622953)
# (('NAME', 'MI', 'JC.TITLE', 'RACE', 'daysexperience'), 0.4021473316761923)
# (('NAME', 'MI', 'JOBCLASS', 'RACE', 'daysexperience'), 0.40128510624210867)
# (('NAME', 'MI', 'JC.TITLE', 'HRSWKD', 'daysexperience'), 0.39658367596519084)
# (('NAME', 'MI', 'JOBCLASS', 'HRSWKD', 'daysexperience'), 0.3956725431771754)
# (('NAME', 'MI', 'RACE', 'SEX', 'EMPTYPE'), 0.3177664118081822)
# (('NAME', 'MI', 'RACE', 'EMPTYPE', 'HRSWKD'), 0.3119501623765727)
# (('NAME', 'MI', 'RACE', 'EMPTYPE', 'RATE'), 0.3108277516377802)
# (('NAME', 'MI', 'RACE', 'EMPTYPE', 'multiple_full_time_jobs'), 0.31005460038758814)
# (('NAME', 'MI', 'RACE', 'EMPTYPE', 'combined_multiple_jobs'), 0.31005453925375137)
# (('NAME', 'MI', 'RACE', 'EMPTYPE', 'STATENUM'), 0.3062887251382048)
# (('NAME', 'MI', 'RACE', 'SEX', 'HRSWKD'), 0.2982929787799181)
# (('NAME', 'MI', 'RACE', 'RATE', 'HRSWKD'), 0.2929890634897747)
# (('NAME', 'MI', 'RACE', 'SEX', 'RATE'), 0.28617540854779566)
# (('NAME', 'MI', 'RACE', 'RATE', 'multiple_full_time_jobs'), 0.2779178413490251)
# (('NAME', 'MI', 'RACE', 'RATE', 'combined_multiple_jobs'), 0.2779178413490251)
# (('NAME', 'MI', 'RACE', 'SEX', 'multiple_full_time_jobs'), 0.277758070582367)
# (('NAME', 'MI', 'RACE', 'SEX', 'combined_multiple_jobs'), 0.2777540740708355)
# (('NAME', 'MI', 'RACE', 'SEX', 'STATENUM'), 0.27657048576147636)
# (('NAME', 'MI', 'RACE', 'RATE', 'STATENUM'), 0.24931437530218248)
# (('NAME', 'MI', 'RACE', 'EMPTYPE', 'daysexperience'), 0.2344002541245478)
# (('NAME', 'MI', 'JOBCLASS', 'RATE', 'daysexperience'), 0.19444407945130548)
# (('NAME', 'MI', 'JC.TITLE', 'multiple_full_time_jobs', 'daysexperience'), 0.19329449552012645)
# (('NAME', 'MI', 'JC.TITLE', 'combined_multiple_jobs', 'daysexperience'), 0.19329449552012645)
# (('NAME', 'MI', 'JOBCLASS', 'multiple_full_time_jobs', 'daysexperience'), 0.19317866029906994)
# (('NAME', 'MI', 'JOBCLASS', 'combined_multiple_jobs', 'daysexperience'), 0.19317866029906994)
# (('NAME', 'MI', 'RACE', 'SEX', 'daysexperience'), 0.17550985319664214)
# (('NAME', 'MI', 'RACE', 'RATE', 'daysexperience'), 0.1699267415533282)
